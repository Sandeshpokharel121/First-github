# %% [markdown]
# <a href="https://colab.research.google.com/github/Sandeshpokharel121/First-github/blob/main/lab_4_Histogram_equalization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Mounting google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image1_path='/content/drive/MyDrive/Lenna_(test_image).png'
image=cv2.imread(image1_path)
plt.imshow(image)
plt.show()

# %%
def img_hist(img):
  hist=np.zeros(256,dtype=int)
  for pixel in img.flatten():
      hist[pixel]+=1
  return hist

# %%
def plot_hist(hist1):
  plt.figure()
  plt.bar(range(256),hist)
  plt.title('Image histogram')
  plt.xlabel('pixel Intensity')
  plt.ylabel('Frequency')

# %%
img= cv2.imread('/content/drive/MyDrive/Lenna_(test_image).png')
histogram1=img_hist(img)
plot_hist(histogram1)

# %%
def hist(img):
  hist=np.zeros(256,dtype=int)
  for pixel in img.flatten():
      hist[pixel]+=1
  return hist

# %%
def hist_eq(img):
  hist=hist(img)
  cdf=hist.cumsum()
  cdf_normalized=cdf*hist.max()/cdf.max()
  return cdf_normalized

# %%
def compute_cdf(img):
  cdf = np.cumsum(img)
  return cdf

# %%
def compute_cdf(img):
  cdf = np.cumsum(img)
  return cdf

# %%
def plot_cdf(cdf):
  plt.figure()
  plt.plot(cdf)
  plt.title('Cumulative distribution function')
  plt.xlabel('pixel Intensity')
  plt.ylabel('Frequency')

# %%
image2_path='/content/drive/MyDrive/Low contrast image.jpg'
image2=cv2.imread(image2_path)
plt.imshow(image2)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
def img_hist(img):
  hist=np.zeros(256,dtype=int)
  for pixel in img.flatten():
      hist[pixel]+=1
  return hist

# %%
def plot_hist(hist):
  plt.figure()
  plt.bar(range(256),hist)
  plt.title('Image histogram')
  plt.xlabel('pixel Intensity')
  plt.ylabel('Frequency')

# %%
img= cv2.imread('/content/drive/MyDrive/Low contrast image.jpg')
histogram2=img_hist(img)
plot_hist(histogram2)

# %%
image3_path='/content/drive/MyDrive/High contrast image.png'
image3=cv2.imread(image3_path)
plt.imshow(image3)
plt.show

# %%
def img_hist(img):
  hist=np.zeros(256,dtype=int)
  for pixel in img.flatten():
      hist[pixel]+=1
  return hist

# %%
def plot_hist(hist):
  plt.figure()
  plt.bar(range(256),hist)
  plt.title('Image histogram')
  plt.xlabel('pixel Intensity')
  plt.ylabel('Frequency')

# %%
img= cv2.imread('/content/drive/MyDrive/High contrast image.png')
histogram3=img_hist(img)
plot_hist(histogram3)

# %%
def hist(img):
  hist=np.zeros(256,dtype=int)
  for pixel in img.flatten():
      hist[pixel]+=1
  return hist

# %%
def hist_eq(img):
  hist=hist(img)
  cdf=hist.cumsum()
  cdf_normalized=cdf*hist.max()/cdf.max()
  return cdf_normalized

# %%
def compute_cdf(img):
  cdf = np.cumsum(img)
  return cdf

# %%
def plot_cdf(cdf):
  plt.figure()
  plt.plot(cdf)
  plt.title('Cumulative distribution function')
  plt.xlabel('pixel Intensity')
  plt.ylabel('Frequency')

# %%
cdf=compute_cdf(histogram3)
plot_cdf(cdf)

# %%
def compute_cdf(img):
  cdf = np.cumsum(img)
  return cdf

# %%
def plot_cdf(cdf):
  plt.figure()
  plt.plot(cdf)
  plt.title('Cumulative distribution function')
  plt.xlabel('pixel Intensity')
  plt.ylabel('Frequency')

# %%
cdf=compute_cdf(histogram1)
plot_cdf(cdf)

# %%
def compute_cdf(img):
  cdf = np.cumsum(img)
  return cdf

# %%
def plot_cdf(cdf):
  plt.figure()
  plt.plot(cdf)
  plt.title('Cumulative distribution function')
  plt.xlabel('pixel Intensity')
  plt.ylabel('Frequency')

# %%
cdf=compute_cdf(histogram2)
plot_cdf(cdf)
